# %% [markdown]
# # Session 1 - January 15, 2026

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
# Generate sample data
np.random.seed(613)  # For reproducibility
x=np.arange(50)
y=np.random.randint(1,100,50)

# %%
# Create a scatter plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, y)

# %%
# Create a bar plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x, y)
# Out:
# <BarContainer object of 50 artists>

# %%
# Create a line plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y)

# %%
# Activity (Slide 15) - Create a histogram
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 7. , 16.2, 25.4, 34.6, 43.8, 53. , 62.2, 71.4, 80.6, 89.8, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
# Same plot as last time
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)

# Adding labels and title
ax.set_title("Total growth over time")
ax.set_ylabel("Total growth")
ax.set_xlabel("Years since start")
fig.tight_layout()

# %%
# Creating dictionary for fonts
font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}

# %%
# Using dictionary on same line plot as before
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1)
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
# Out:
# Text(0.5, 0, 'Years since start')

# %%
# Customizing marker style
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, y, marker='*', color = "indigo")

# %%
# Connect points with a line of specified colour, width, and style
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y, marker='*', color = 'indigo', 
linestyle = '--', linewidth = 2)

# %%
# Using hex code for colour
fig, ax = plt.subplots(figsize=(5, 3))

ax.plot(x,y,marker='*', color = '#7425b9', linestyle = '--', linewidth = 2)

# %%
# Customizing marker size and marker edge + face colours
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,marker='*', 
    markersize = 12, 
    # color = '#7425b9', 
    linestyle = '--', 
    linewidth = 2, 
    markeredgecolor = '#fa9359', 
    markerfacecolor = '#000000' )

# %%
# Add gridlines
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,marker='*', 
    markersize = 12, 
    # color = '#7425b9', 
    linestyle = '--', 
    linewidth = 2, 
    markeredgecolor = '#fa9359', 
    markerfacecolor = '#000000' )
ax.grid(axis = 'y')

# %%
# Activity (Slide 27) - Customize appearance of gridlines
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,marker='*',
    markersize = 12, 
    # color = '#7425b9', 
    linestyle = '--', 
    linewidth = 2, 
    markeredgecolor = '#fa9359', 
    markerfacecolor = '#000000' )
ax.grid(axis = 'y', color = 'gray', linestyle = '-.', linewidth = 0.5)

# %%
# Activity (Slide 31) - Pick graph from Python Graph Gallery

# I chose Number 39 - Boxplot with Jitters

# Importing extra library
import seaborn as sns

# %%
# Adding dataset:
a = pd.DataFrame({ 'group' : np.repeat('A',500), 'value': np.random.normal(10, 5, 500) })
b = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(13, 1.2, 500) })
c = pd.DataFrame({ 'group' : np.repeat('B',500), 'value': np.random.normal(18, 1.2, 500) })
d = pd.DataFrame({ 'group' : np.repeat('C',20), 'value': np.random.normal(25, 4, 20) })
e = pd.DataFrame({ 'group' : np.repeat('D',100), 'value': np.random.uniform(12, size=100) })
df = pd.concat([a,b,c,d,e])

# Making boxplot
ax = sns.boxplot(x='group', y='value', data=df)
# Add stripplot
ax = sns.stripplot(x='group', y='value', data=df, color="orange", jitter=0.2, size=2.5)

# Add title
plt.title("Boxplot with jitter", loc="left")

# Show the graph
plt.show()

# %% [markdown]
# Please see the assignment-1.md file in the participation folder for written comments about the quality of the replicated visualization.

# %% [markdown]
# # Session 2 - January 20, 2026

# %%
# Create figure container and axes subplot
fig, ax = plt.subplots(figsize=(5, 3))

# %%
# Make scatter plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y)
fig.show()

# %% [markdown]
# Please see the assignment-1.md file in the participation folder for comments on the Slide 11 Activity for Lecture 4 ("How do we choose the 'right' visualization?").

# %% [markdown]
# # Session 3 - January 22, 2026

# %% [markdown]
# Please see the assignment-1.md file in the participation folder for comments corresponding to the activity on Slide 21 in Lecture 3 ("Reproducible").

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# Generate sample data
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)

# %%
# Activity (Slide 5) - Line plot with two lines
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y1)
ax.plot(x, y2)
# fig.show()

# %%
# Adding a legend to the plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y1, label='Line 1')
ax.plot(x, y2, label='Line 2')
ax.legend(loc='lower right')

# %%
# Modifying the legend
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='lower right',
    frameon = True, # add frame
    fontsize = 12, # font size
    ncol = 2, # number of columns
    shadow = True )

# %%
# Move legend outside the plot area
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='upper left',
    bbox_to_anchor =(1, 1))

# %%
# Annotating plot points
# Create scatter plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

# Specify coordinates and text
ax.text(10, 95, "This value is important!")
# Out:
# Text(10, 95, 'This value is important!')

# %%
# Modify text annotations

# Same scatter plot as before
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

ax.text(10, 95, "This value is important!",
    ha='center', # alignment
    color = 'red', # font colour
    size = 20) # font size
# Out:
# Text(10, 95, 'This value is important!')

# %%
# Position text annotations

# Empty axes
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])

# Add text in different coordinate systems
ax.text(1, 5, ". Data:(1, 5)", transform=ax.transData)
ax.text(0.5, 0.1, ". Axes:(0.5, 0.1)", transform=ax.transAxes)
ax.text(0.2, 0.2, ". Figure:(0.2, 0.2)", transform=fig.transFigure)
# Out:
# Text(0.2, 0.2, '. Figure:(0.2, 0.2)')

# %%
# Annotating with arrows

# Create scatter plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

# Add annotation with arrow
ax.annotate('This is important!', xy=(10, 95), xytext=(20, 94),
arrowprops=dict(facecolor='black'))
# Out:
# Text(20, 94, 'This is important!')

# %%
# Modifying arrows

# Same scatter plot as before
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

# Add annotation with customized arrow
ax.annotate('This is important!',
    xy=(10, 95), xytext=(20, 94),
    arrowprops = dict(arrowstyle = "wedge", color = "hotpink"))
# Out:
# Text(20, 94, 'This is important!')

# %%
# Remvoing tick marks and labels

# Same scatter plot as before
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

# Use locator and formatter
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
# Defining max number of ticks

# Same scatter plot as before
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

# Use max number locator
ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
# Setting tick intervals

# Same scatter plot as before
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

# Use multiple locator
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %%
# Rotating axis labels

# Same scatter plot as before
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

# Use rotation
plt.xticks(rotation=45, ha='right')
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
# Activity (Slide 23) - Modifying axis title fonts
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.set_xlabel("Shiny New X Axis!", fontdict={'family':'serif','color':'indigo','size':14})
ax.legend(loc='lower right')

# %%
# View pre-made styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Using style from list
plt.style.use('Solarize_Light2')

# Recreate plot with new style
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)

# %% [markdown]
# # Session 4 - January 27, 2026
