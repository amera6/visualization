# %% [markdown]
# # Covers Lecture 4 Content
# ## How do we choose the right visualization?

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
# Create figure container and axes subplot
fig, ax = plt.subplots(figsize=(5, 3))

# %%
# Generate sample data
np.random.seed(613)  # For reproducibility
x=np.arange(50)
y=np.random.randint(1,100,50)

# Make scatter plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y)
fig.show()
# Out:
# C:\Users\adani\AppData\Local\Temp\ipykernel_23508\299504444.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# Please see the assignment-1.md file in the participation folder for comments on the Slide 11 Activity for Lecture 4.
